# %%
import plotly
import plotly.express as px
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd

# %%
data = pd.read_csv('Airline-Sentiment-2-w-AA.csv', encoding=("ISO-8859-1"), low_memory=False)

# %%
neutral = pd.DataFrame(data = data[data.airline_sentiment == 'neutral'].groupby('airline').count())

# %%
neutral.reset_index(inplace=True)

# %%
neutral
# Out:
#           airline  _unit_id  _golden  _unit_state  _trusted_judgments  \
# 0        American       463      463          463                 463
# 1           Delta       723      723          723                 723
# 2       Southwest       664      664          664                 664
# 3      US Airways       381      381          381                 381
# 4          United       697      697          697                 697
# 5  Virgin America       171      171          171                 171
#
#    _last_judgment_at  airline_sentiment  airline_sentiment:confidence  \
# 0                461                463                           463
# 1                723                723                           723
# 2                662                664                           664
# 3                381                381                           381
# 4                696                697                           697
# ...

# %%
neutral = neutral[['airline','airline_sentiment']].copy()

# %%
neutral
# Out:
#           airline  airline_sentiment
# 0        American                463
# 1           Delta                723
# 2       Southwest                664
# 3      US Airways                381
# 4          United                697
# 5  Virgin America                171

# %%
fig = px.histogram(neutral, x="airline", y="airline_sentiment")
fig.show()
# Out:
# <div>                            <div id="c6c395ed-0d20-4f52-a812-1b0ffcd25d08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6c395ed-0d20-4f52-a812-1b0ffcd25d08")) {                    Plotly.newPlot(                        "c6c395ed-0d20-4f52-a812-1b0ffcd25d08",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"airline=%{x}<br>sum of airline_sentiment=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["American","Delta","Southwest","US Airways","United","Virgin America"],"xaxis":"x","y":[463,723,664,381,697,171],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"h
# ...

# %%
data.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  681448150    False   finalized                   3      2/25/15 5:24
# 1  681448153    False   finalized                   3      2/25/15 1:53
# 2  681448156    False   finalized                   3     2/25/15 10:01
# 3  681448158    False   finalized                   3      2/25/15 3:05
# 4  681448159    False   finalized                   3      2/25/15 5:50
#
#   airline_sentiment  airline_sentiment:confidence negativereason  \
# 0           neutral                        1.0000            NaN
# 1          positive                        0.3486            NaN
# 2           neutral                        0.6837            NaN
# 3          negative                        1.0000     Bad Flight
# 4          negative                        1.0000     Can't Tell
#
#    negativereason:confidence         airline airline_sentiment_gold  \
# 0                        NaN  Virgin America                    NaN
# ...

# %%
delta = data.query('airline == "Delta"')

# %%
am = data.query('airline == "American"')

# %%
sw = data.query('airline == "Southwest"')

# %%
usa = data.query('airline == "US Airways"')

# %%
un = data.query('airline == "United"')

# %%
va = data.query('airline == "Virgin America"')

# %%
delta
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 6746   681457141    False   finalized                   3      2/25/15 1:45
# 6747   681457143    False   finalized                   3      2/25/15 8:25
# 6748   681457144    False   finalized                   3      2/25/15 8:53
# 6749   681457146    False   finalized                   3      2/25/15 8:20
# 6750   681457149    False   finalized                   3      2/25/15 1:04
# ...          ...      ...         ...                 ...               ...
# 8963   681460003    False   finalized                   3      2/25/15 7:11
# 8964   681460005    False   finalized                   3      2/25/15 9:44
# 8965   681460006    False   finalized                   3      2/25/15 4:52
# 12038  681472920     True      golden                 231               NaN
# 12039  681475891     True      golden                 245               NaN
#
#       airline_sentiment  airline_sentiment:confidence  \
# ...

# %%
fig=px.histogram(delta, x='airline_sentiment')
fig.show()
# Out:
# <div>                            <div id="a2ee0501-60aa-4391-80e4-77188363d509" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2ee0501-60aa-4391-80e4-77188363d509")) {                    Plotly.newPlot(                        "a2ee0501-60aa-4391-80e4-77188363d509",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"airline_sentiment=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["positive","neutral","neutral","negative","negative","neutral","neutral","negative","negative","negative","negative","neutral","negative","positive","neutral","neutral","negative","negative","neutral","neutral","neutral
# ...

# %%
fig = px.pie(delta, names='airline_sentiment')
fig.show()
fig = px.pie(am, names='airline_sentiment')
fig.show()
fig = px.pie(sw, names='airline_sentiment')
fig.show()
fig = px.pie(usa, names='airline_sentiment')
fig.show()
fig = px.pie(un, names='airline_sentiment')
fig.show()
fig = px.pie(va, names='airline_sentiment')
fig.show()
# Out:
# <div>                            <div id="0530cdcf-4335-4c7b-9557-dfc8adcfda69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0530cdcf-4335-4c7b-9557-dfc8adcfda69")) {                    Plotly.newPlot(                        "0530cdcf-4335-4c7b-9557-dfc8adcfda69",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"airline_sentiment=%{label}<extra></extra>","labels":["positive","neutral","neutral","negative","negative","neutral","neutral","negative","negative","negative","negative","neutral","negative","positive","neutral","neutral","negative","negative","neutral","neutral","neutral","negative","negative","neutral","negative","positive","positive","neutral","positive","positive","neutral","negative","negative","negati
# ...

# %%
data.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  681448150    False   finalized                   3      2/25/15 5:24
# 1  681448153    False   finalized                   3      2/25/15 1:53
# 2  681448156    False   finalized                   3     2/25/15 10:01
# 3  681448158    False   finalized                   3      2/25/15 3:05
# 4  681448159    False   finalized                   3      2/25/15 5:50
#
#   airline_sentiment  airline_sentiment:confidence negativereason  \
# 0           neutral                        1.0000            NaN
# 1          positive                        0.3486            NaN
# 2           neutral                        0.6837            NaN
# 3          negative                        1.0000     Bad Flight
# 4          negative                        1.0000     Can't Tell
#
#    negativereason:confidence         airline airline_sentiment_gold  \
# 0                        NaN  Virgin America                    NaN
# ...

# %%
positive = pd.DataFrame(data = data[data.airline_sentiment == 'positive'].groupby('airline').count())

# %%
positive.reset_index(inplace=True)

# %%
positive = positive[['airline','airline_sentiment']].copy()

# %%
positive
# Out:
#           airline  airline_sentiment
# 0        American                336
# 1           Delta                544
# 2       Southwest                570
# 3      US Airways                269
# 4          United                492
# 5  Virgin America                152

# %%
fig = px.histogram(positive, x="airline", y="airline_sentiment")
fig.show()
# Out:
# <div>                            <div id="3392f3c5-21a5-4d9f-b511-c477430f9ec3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3392f3c5-21a5-4d9f-b511-c477430f9ec3")) {                    Plotly.newPlot(                        "3392f3c5-21a5-4d9f-b511-c477430f9ec3",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"airline=%{x}<br>sum of airline_sentiment=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["American","Delta","Southwest","US Airways","United","Virgin America"],"xaxis":"x","y":[336,544,570,269,492,152],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"h
# ...
